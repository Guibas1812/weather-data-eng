# %%
import requests
from dotenv import load_dotenv
import boto3
from pathlib import Path
import pandas as pd
import json

load_dotenv()  # reads .env, sets env variables

s3 = boto3.client("s3")
bucket_name = "weather-data-eng" #bucket_name

tokyo_df = pd.read_json(s3.get_object(
            Bucket=bucket_name,
            Key="bronze/activities/Tokyo/Tokyo_activities.json")['Body'])

tokyo_df.head(20)
# Out:
#                  type                                           features
# 0   FeatureCollection  {'type': 'Feature', 'id': '11242239', 'geometr...
# 1   FeatureCollection  {'type': 'Feature', 'id': '11242235', 'geometr...
# 2   FeatureCollection  {'type': 'Feature', 'id': '11611753', 'geometr...
# 3   FeatureCollection  {'type': 'Feature', 'id': '11219628', 'geometr...
# 4   FeatureCollection  {'type': 'Feature', 'id': '11558819', 'geometr...
# 5   FeatureCollection  {'type': 'Feature', 'id': '11373744', 'geometr...
# 6   FeatureCollection  {'type': 'Feature', 'id': '11281563', 'geometr...
# 7   FeatureCollection  {'type': 'Feature', 'id': '11373743', 'geometr...
# 8   FeatureCollection  {'type': 'Feature', 'id': '11465920', 'geometr...
# 9   FeatureCollection  {'type': 'Feature', 'id': '11650980', 'geometr...
# 10  FeatureCollection  {'type': 'Feature', 'id': '11501818', 'geometr...
# 11  FeatureCollection  {'type': 'Feature', 'id': '11663393', 'geometr...
# ...

# %%
print(tokyo_df.keys())              # should show dict_keys(['type', 'features'])
print(len(tokyo_df["features"]))    # how many attractions were found
print(tokyo_df["features"][0])      # look at one actual feature, fully
# Out:
# Index(['type', 'features'], dtype='object')
# 50
# {'type': 'Feature', 'id': '11242239', 'geometry': {'type': 'Point', 'coordinates': [139.7506561, 35.6838112]}, 'properties': {'xid': 'W534754971', 'name': 'Imperial Palace', 'dist': 148.1660573, 'rate': 3, 'osm': 'way/534754971', 'wikidata': 'Q500681', 'kinds': 'palaces,architecture,historic_architecture,historic,historical_places,interesting_places,historic_districts'}}
